# %%
import pandas as pd
import numpy as np
from prophet import Prophet
import matplotlib.pyplot as plt

# Simulated migration data
df = pd.DataFrame({
    'ds': pd.date_range(start='2020-01-01', periods=36, freq='M'),
    'y': np.random.randint(1000, 5000, size=36)
})

# Build and train model
model = Prophet()
model.fit(df)

# Forecast the next 12 months
future = model.make_future_dataframe(periods=12, freq='M')
forecast = model.predict(future)

# Plot
model.plot(forecast)
plt.title("Simulated Migration Forecast")
plt.show()
# Out:
# Importing plotly failed. Interactive plots will not work.
# /tmp/ipykernel_22970/3152762563.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'ds': pd.date_range(start='2020-01-01', periods=36, freq='M'),
# 14:15:16 - cmdstanpy - INFO - Chain [1] start processing
# 14:15:17 - cmdstanpy - INFO - Chain [1] done processing
# /home/codebonds/immigration-predictor/venv/lib/python3.12/site-packages/prophet/forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(
